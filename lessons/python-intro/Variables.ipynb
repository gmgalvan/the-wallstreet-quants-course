# %% [markdown]
# # 🐍 Python Intro
# ## 📋 Table of Contents
#
# 1. 🏷️ Variables
# 2. 📊 Basic Data Types (Numbers, Strings, Booleans)
# 3. 📝 Lists
# 4. 🔑 Dictionaries
# 5. ⚙️ Functions
# 6. 🔀 If / Else Statements
# 7. 🔄 Loops (While, For)
# 8. ✨ Some Syntactic Sugar

# %% [markdown]
# #### 💬 Comments

# %%
# Here is a comment. It follows a hashtag

# %% [markdown]
# 📝 Note: Comments are ignored by Python and useful for explaining your code. Use them generously!

# %% [markdown]
# ## 🏷️ Variables

# %%
# variable assignment using "="
aapl_ret = 0.01
market_ret = 0.02

# %%
# print statement outputs variable values
print (aapl_ret)
print (market_ret)
# Out:
# 0.01
# 0.02

# %%
aapl_ret
# Out:
# 0.01

# %%
# variables can be defined in terms of other variables
excess_ret = aapl_ret - market_ret
print (excess_ret)
# Out:
# -0.01
